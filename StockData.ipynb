# %%
import pandas as pd 
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT", "TSLA"]

# %%
AppleTicker = ["AAPL"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2020-12-12")
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
apple = yf.download(AppleTicker, start = "2010-01-01", end = "2020-12-12")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.593426  43.441975  27.933924  92.163887  18.817513  24.105360
# 2010-01-05  6.604825  44.864773  27.864237  91.050545  18.589882  24.113148
# 2010-01-06  6.499768  46.225727  27.716166  90.459076  18.583282  23.965164
# 2010-01-07  6.487752  48.097031  27.724878  90.145927  18.537094  23.715933
# 2010-01-08  6.530883  47.633064  27.768419  91.050545  18.194000  23.879499
#
#                     Close                        ...       Open             \
#            TSLA      AAPL         BA        DIS  ...         KO       MSFT
# Date                                             ...
# 2010-01-04  NaN  7.643214  56.180000  32.070000  ...  28.580000  30.620001
# 2010-01-05  NaN  7.656428  58.020000  31.990000  ...  28.424999  30.850000
# ...

# %%
stocks.to_csv("Stocks.csv")

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2756 entries, 2010-01-04 to 2020-12-11
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2756 non-null   float64
#  1   (Adj Close, BA)    2756 non-null   float64
#  2   (Adj Close, DIS)   2756 non-null   float64
#  3   (Adj Close, IBM)   2756 non-null   float64
#  4   (Adj Close, KO)    2756 non-null   float64
#  5   (Adj Close, MSFT)  2756 non-null   float64
#  6   (Adj Close, TSLA)  2634 non-null   float64
#  7   (Close, AAPL)      2756 non-null   float64
#  8   (Close, BA)        2756 non-null   float64
#  9   (Close, DIS)       2756 non-null   float64
#  10  (Close, IBM)       2756 non-null   float64
#  11  (Close, KO)        2756 non-null   float64
#  12  (Close, MSFT)      2756 non-null   float64
#  13  (Close, TSLA)      2634 non-null   float64
#  14  (High, AAPL)       2756 non-null   float64
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header = [0, 1], index_col=[0], parse_dates=[0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.593426  43.441975  27.933924  92.163887  18.817513  24.105360
# 2010-01-05  6.604825  44.864773  27.864237  91.050545  18.589882  24.113148
# 2010-01-06  6.499768  46.225727  27.716166  90.459076  18.583282  23.965164
# 2010-01-07  6.487752  48.097031  27.724878  90.145927  18.537094  23.715933
# 2010-01-08  6.530883  47.633064  27.768419  91.050545  18.194000  23.879499
#
#                     Close                        ...       Open             \
#            TSLA      AAPL         BA        DIS  ...         KO       MSFT
# Date                                             ...
# 2010-01-04  NaN  7.643214  56.180000  32.070000  ...  28.580000  30.620001
# 2010-01-05  NaN  7.656428  58.020000  31.990000  ...  28.424999  30.850000
# ...

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.593426  43.441975  27.933924  92.163887  18.817513  24.105360
# 2010-01-05  6.604825  44.864773  27.864237  91.050545  18.589882  24.113148
# 2010-01-06  6.499768  46.225727  27.716166  90.459076  18.583282  23.965164
# 2010-01-07  6.487752  48.097031  27.724878  90.145927  18.537094  23.715933
# 2010-01-08  6.530883  47.633064  27.768419  91.050545  18.194000  23.879499
#
#                     Close                        ...       Open             \
#            TSLA      AAPL         BA        DIS  ...         KO       MSFT
# Date                                             ...
# 2010-01-04  NaN  7.643214  56.180000  32.070000  ...  28.580000  30.620001
# 2010-01-05  NaN  7.656428  58.020000  31.990000  ...  28.424999  30.850000
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2756 entries, 2010-01-04 to 2020-12-11
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2756 non-null   float64
#  1   (Adj Close, BA)    2756 non-null   float64
#  2   (Adj Close, DIS)   2756 non-null   float64
#  3   (Adj Close, IBM)   2756 non-null   float64
#  4   (Adj Close, KO)    2756 non-null   float64
#  5   (Adj Close, MSFT)  2756 non-null   float64
#  6   (Adj Close, TSLA)  2634 non-null   float64
#  7   (Close, AAPL)      2756 non-null   float64
#  8   (Close, BA)        2756 non-null   float64
#  9   (Close, DIS)       2756 non-null   float64
#  10  (Close, IBM)       2756 non-null   float64
#  11  (Close, KO)        2756 non-null   float64
#  12  (Close, MSFT)      2756 non-null   float64
#  13  (Close, TSLA)      2634 non-null   float64
#  14  (High, AAPL)       2756 non-null   float64
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           BA          DIS          IBM           KO
# count  2756.000000  2756.000000  2756.000000  2756.000000  2756.000000
# mean     31.656901   154.471303    81.159276   126.761357    35.015891
# std      24.180053   105.455836    34.874839    15.855132     9.170266
# min       5.916861    43.441975    25.536150    85.163742    16.794077
# 25%      15.429378    61.501915    44.644627   119.193800    29.075827
# 50%      24.897592   117.721169    90.978844   128.552780    34.642195
# 75%      41.442682   197.144436   106.343277   138.496925    41.160037
# max     133.948898   430.299988   175.720001   158.909164    58.140400
#
#                                        Close                            ...  \
#               MSFT         TSLA         AAPL           BA          DIS  ...
# count  2756.000000  2634.000000  2756.000000  2756.000000  2756.000000  ...
# ...

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT  \
# Date
# 2010-01-04  7.643214  56.180000  32.070000  132.449997  28.520000  30.950001
# 2010-01-05  7.656428  58.020000  31.990000  130.850006  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  130.000000  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  129.550003  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  130.850006  27.575001  30.660000
#
#             TSLA
# Date
# 2010-01-04   NaN
# 2010-01-05   NaN
# 2010-01-06   NaN
# 2010-01-07   NaN
# 2010-01-08   NaN

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# BA       56.180000
# DIS      32.070000
# IBM     132.449997
# KO       28.520000
# MSFT     30.950001
# TSLA           NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                    AAPL          BA         DIS         IBM          KO  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172887  103.275187   99.750546   98.792004   98.790318
# 2010-01-06    98.579504  106.407972   99.220455   98.150248   98.755261
# 2010-01-07    98.397272  110.715558   99.251638   97.810499   98.509814
# 2010-01-08    99.051449  109.647558   99.407544   98.792004   96.686537
# ...                 ...         ...         ...         ...         ...
# 2020-12-07  1619.083233  423.940899  479.201728   94.148735  185.799442
# 2020-12-08  1627.325803  421.092926  479.326482   94.911289  186.465636
# 2020-12-09  1593.308720  413.065141  481.540362   95.726692  186.991588
# 2020-12-10  1612.410620  417.283716  482.351119   94.345037  186.009812
# 2020-12-11  1601.551390  409.985761  547.926420   93.824084  187.061703
#
#                   MSFT  TSLA
# Date
# 2010-01-04  100.000000   NaN
# 2010-01-05  100.032305   NaN
# ...

# %%
#A normalised plot where all stocks are set to 100 points
norm.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.593426  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656428   6.604825  601904800
# 2010-01-06  7.656428  7.686786  7.526786  7.534643   6.499768  552160000
# 2010-01-07  7.562500  7.571429  7.466072  7.520714   6.487752  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.530883  447610800

# %%
apple.Close.diff(periods = 1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013214
# 2010-01-06   -0.121786
# 2010-01-07   -0.013928
# 2010-01-08    0.050000
#                 ...
# 2020-12-07    1.500000
# 2020-12-08    0.629997
# 2020-12-09   -2.599998
# 2020-12-10    1.459999
# 2020-12-11   -0.829994
# Name: Close, Length: 2756, dtype: float64

# %%
apple["Diff2"] = apple.Close.diff(periods = 1)

# %%
apple.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.593426  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656428   6.604825  601904800
# 2010-01-06  7.656428  7.686786  7.526786  7.534643   6.499768  552160000
# 2010-01-07  7.562500  7.571429  7.466072  7.520714   6.487752  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.530883  447610800
# 2010-01-11  7.600000  7.607143  7.444643  7.503929   6.473271  462229600
# 2010-01-12  7.471071  7.491786  7.372143  7.418571   6.399639  594459600
# 2010-01-13  7.423929  7.533214  7.289286  7.523214   6.489907  605892000
# 2010-01-14  7.503929  7.516428  7.465000  7.479643   6.452320  432894000
# 2010-01-15  7.533214  7.557143  7.352500  7.354643   6.344490  594067600
#
#                Diff2
# Date
# 2010-01-04       NaN
# 2010-01-05  0.013214
# 2010-01-06 -0.121786
# 2010-01-07 -0.013928
# 2010-01-08  0.050000
# ...

# %%
apple["pct_change2"] = apple.Close.diff(periods = 1).mul(100)

# %%
apple.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.593426  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656428   6.604825  601904800
# 2010-01-06  7.656428  7.686786  7.526786  7.534643   6.499768  552160000
# 2010-01-07  7.562500  7.571429  7.466072  7.520714   6.487752  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.530883  447610800
# 2010-01-11  7.600000  7.607143  7.444643  7.503929   6.473271  462229600
# 2010-01-12  7.471071  7.491786  7.372143  7.418571   6.399639  594459600
# 2010-01-13  7.423929  7.533214  7.289286  7.523214   6.489907  605892000
# 2010-01-14  7.503929  7.516428  7.465000  7.479643   6.452320  432894000
# 2010-01-15  7.533214  7.557143  7.352500  7.354643   6.344490  594067600
#
#                Diff2  pct_change2
# Date
# 2010-01-04       NaN          NaN
# 2010-01-05  0.013214     1.321411
# 2010-01-06 -0.121786   -12.178564
# ...

# %%
apple.Close.resample("BM").last().pct_change(periods = 1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847041
# 2010-04-30    11.102126
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31     2.822344
# Freq: BM, Name: Close, Length: 132, dtype: float64

# %%
#How to create a DataFrame
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656428
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
ret = aapl.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008822

# %%
ret.info
# Out:
# <bound method DataFrame.info of                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008822
# ...              ...
# 2020-12-07  0.012270
# 2020-12-08  0.005091
# 2020-12-09 -0.020904
# 2020-12-10  0.011989
# 2020-12-11 -0.006735
#
# [2755 rows x 1 columns]>

# %%
ret.plot(kind = "hist", figsize = (12, 8), bins = 100)
plt.show()

# %%
#Calculating daily then annualised returns 
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.001166
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.017831
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017831
# dtype: float64

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    0.293929
# dtype: float64

# %%
ann_var_Return = ret.var() * 252
ann_var_Return
# Out:
# AAPL    0.080118
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Return)
ann_std_Returns
# Out:
# AAPL    0.283052
# dtype: float64

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT  \
# Date
# 2010-01-04  7.643214  56.180000  32.070000  132.449997  28.520000  30.950001
# 2010-01-05  7.656428  58.020000  31.990000  130.850006  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  130.000000  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  129.550003  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  130.850006  27.575001  30.660000
#
#             TSLA
# Date
# 2010-01-04   NaN
# 2010-01-05   NaN
# 2010-01-06   NaN
# 2010-01-07   NaN
# 2010-01-08   NaN

# %%
returns = close.pct_change().dropna()
returns
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-06-30 -0.018113 -0.004600 -0.024768 -0.012871 -0.004173 -0.012870
# 2010-07-01 -0.012126 -0.007809 -0.000317 -0.007370 -0.001796  0.006519
# 2010-07-02 -0.006198 -0.005140 -0.003493 -0.005793  0.000400  0.004750
# 2010-07-06  0.006844 -0.009364  0.010835  0.013130  0.007592  0.023636
# 2010-07-07  0.040381  0.031617  0.044767  0.028673  0.020623  0.020151
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-07  0.012270  0.023463 -0.002984 -0.019654 -0.015970 -0.000327
# 2020-12-08  0.005091 -0.006718  0.000260  0.008099  0.003586  0.008027
# 2020-12-09 -0.020904 -0.019064  0.004619  0.008591  0.002821 -0.019490
# 2020-12-10  0.011989  0.010213  0.001684 -0.014433 -0.005250 -0.006043
# 2020-12-11 -0.006735 -0.017489  0.135949 -0.005522  0.005655  0.013015
#
#                 TSLA
# Date
# 2010-06-30 -0.002512
# 2010-07-01 -0.078472
# 2010-07-02 -0.125683
# ...

# %%
returns.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-06-30 -0.018113 -0.004600 -0.024768 -0.012871 -0.004173 -0.012870
# 2010-07-01 -0.012126 -0.007809 -0.000317 -0.007370 -0.001796  0.006519
# 2010-07-02 -0.006198 -0.005140 -0.003493 -0.005793  0.000400  0.004750
# 2010-07-06  0.006844 -0.009364  0.010835  0.013130  0.007592  0.023636
# 2010-07-07  0.040381  0.031617  0.044767  0.028673  0.020623  0.020151
#
#                 TSLA
# Date
# 2010-06-30 -0.002512
# 2010-07-01 -0.078472
# 2010-07-02 -0.125683
# 2010-07-06 -0.160938
# 2010-07-07 -0.019243

# %%
#Transposed and locked in mean and std in dataframe
summary = returns.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001143  0.017723
# BA    0.000745  0.022462
# DIS   0.000766  0.015687
# IBM   0.000099  0.014224
# KO    0.000347  0.011072
# MSFT  0.000970  0.016073
# TSLA  0.002469  0.035487

# %%
#annualised the dataframe from daily to yearly using no. of trading days
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.287996  0.281349
# BA    0.187725  0.356565
# DIS   0.193046  0.249023
# IBM   0.024984  0.225798
# KO    0.087444  0.175757
# MSFT  0.244492  0.255147
# TSLA  0.622162  0.563335

# %%
summary.plot.scatter(x = "std", y = "mean", figsize = (12, 8), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size =15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %%
returns.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT  \
# Date
# 2010-06-30 -0.018113 -0.004600 -0.024768 -0.012871 -0.004173 -0.012870
# 2010-07-01 -0.012126 -0.007809 -0.000317 -0.007370 -0.001796  0.006519
# 2010-07-02 -0.006198 -0.005140 -0.003493 -0.005793  0.000400  0.004750
# 2010-07-06  0.006844 -0.009364  0.010835  0.013130  0.007592  0.023636
# 2010-07-07  0.040381  0.031617  0.044767  0.028673  0.020623  0.020151
#
#                 TSLA
# Date
# 2010-06-30 -0.002512
# 2010-07-01 -0.078472
# 2010-07-02 -0.125683
# 2010-07-06 -0.160938
# 2010-07-07 -0.019243

# %%
returns.cov()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT      TSLA
# AAPL  0.000314  0.000154  0.000110  0.000108  0.000066  0.000157  0.000193
# BA    0.000154  0.000505  0.000187  0.000160  0.000118  0.000150  0.000205
# DIS   0.000110  0.000187  0.000246  0.000110  0.000085  0.000121  0.000151
# IBM   0.000108  0.000160  0.000110  0.000202  0.000078  0.000121  0.000124
# KO    0.000066  0.000118  0.000085  0.000078  0.000123  0.000076  0.000079
# MSFT  0.000157  0.000150  0.000121  0.000121  0.000076  0.000258  0.000184
# TSLA  0.000193  0.000205  0.000151  0.000124  0.000079  0.000184  0.001259

# %%
returns.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT      TSLA
# AAPL  1.000000  0.386516  0.397333  0.426595  0.335785  0.551379  0.306708
# BA    0.386516  1.000000  0.531737  0.499683  0.474400  0.415532  0.257157
# DIS   0.397333  0.531737  1.000000  0.494583  0.487138  0.478498  0.270715
# IBM   0.426595  0.499683  0.494583  1.000000  0.498419  0.528256  0.245407
# KO    0.335785  0.474400  0.487138  0.498419  1.000000  0.428867  0.200734
# MSFT  0.551379  0.415532  0.478498  0.528256  0.428867  1.000000  0.322496
# TSLA  0.306708  0.257157  0.270715  0.245407  0.200734  0.322496  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(returns.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()
